# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.google.com/search?q=manzana&tbm=nws"

# %%
page = requests.get(url).text
soup = BeautifulSoup(page, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="es">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <noscript>
#    <meta content="0;url=/search?q=manzana&amp;tbm=nws&amp;ie=UTF-8&amp;gbv=1&amp;sei=qFtRXLafFYmtUvqMrrAB" http-equiv="refresh"/>
#    <style>
#     table,div,span,p{display:none}
#    </style>
#    <div style="display:block">
#     Por favor, haz clic
#     <a href="/search?q=manzana&amp;tbm=nws&amp;ie=UTF-8&amp;gbv=1&amp;sei=qFtRXLafFYmtUvqMrrAB">
#      aquí
#     </a>
#     si no has sido redireccionado en unos segundos.
#    </div>
#   </noscript>
#   <title>
#    manzana - Buscar con Google
#   </title>
#   <style>
# ...
